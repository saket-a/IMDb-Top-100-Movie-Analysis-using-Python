# %%
# Filtering out the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# We have the data for the 100 top-rated movies from a certain time period along with various pieces of information about the movie, its actors, and the voters who have rated these movies online. We will try to find some interesting insights into these movies and their voters, using Python.

# %% [markdown]
# ##  Reading the data

# %% [markdown]
# - ### Read the Movies Data.
#
# Reading the movies data file provided and storing it in a dataframe `movies`.

# %%
# Read the csv file using 'read_csv'.
data = pd.read_csv('Movie_Data.csv')

# %% [markdown]
# - ### Inspect the Dataframe
#
# Inspecting the dataframe for dimensions, null-values, and summary of different numeric columns.

# %%
# Check the number of rows and columns in the dataframe
print("Rows: ",data.shape[0],"\nColumns: ",data.shape[1])
# Out:
# Rows:  100
# Columns:  62

# %%
# Check the column-wise info of the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
# Check the summary for the numeric columns 
data.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %% [markdown]
# ## Data Analysis
#
# Now that we have loaded the dataset and inspected it, we see that most of the data is in place. As of now, no data cleaning is required, so let's start with some data manipulation, analysis, and visualisation to get various insights about the data.

# %% [markdown]
# -  ### Making the numbers readable
#
# These numbers in the `budget` and `gross` are too big, compromising its readability. Let's convert the unit of the `budget` and `gross` columns from `$` to `million $` first.

# %%
# Divide the 'gross' and 'budget' columns by 1000000 to convert '$' to 'million $'
data['Gross'] = (data['Gross']/1000000).round(2)
data['budget'] = (data['budget']/1000000).round(2)

# %% [markdown]
# -  ### Calculating Profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`.
#     4. Plot a scatter or a joint plot between the columns `budget` and `profit` and write a few words on what you observed.
#     5. Extract the movies with a negative profit and store them in a new dataframe - `neg_profit`

# %%
# Create the new column named 'profit' by subtracting the 'budget' column from the 'gross' column
data['profit'] = data['Gross'] - data['budget']
data
# Out:
#                                            Title  title_year  budget   Gross  \
# 0                                     La La Land        2016    30.0  151.10
# 1                                       Zootopia        2016   150.0  341.27
# 2                                           Lion        2016    12.0   51.74
# 3                                        Arrival        2016    47.0  100.55
# 4                          Manchester by the Sea        2016     9.0   47.70
# ..                                           ...         ...     ...     ...
# 95                                      Whiplash        2014     3.3   13.09
# 96                               Before Midnight        2013     3.0    8.11
# 97    Star Wars: Episode VII - The Force Awakens        2015   245.0  936.66
# 98  Harry Potter and the Deathly Hallows: Part I        2010   150.0  296.35
# 99                       Tucker and Dale vs Evil        2010     5.0    0.22
#
# ...

# %%
# Sort the dataframe with the 'profit' column as reference using the 'sort_values' function.
data.sort_values(by=['profit'], ascending=False, inplace=True)
data
# Out:
#                                          Title  title_year  budget   Gross  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0  936.66
# 11                                The Avengers        2012   220.0  623.28
# 47                                    Deadpool        2016    58.0  363.02
# 32             The Hunger Games: Catching Fire        2013   130.0  424.65
# 12                                 Toy Story 3        2010   200.0  414.98
# ..                                         ...         ...     ...     ...
# 46                 Scott Pilgrim vs. the World        2010    60.0   31.49
# 7                                      Tangled        2010   260.0  200.81
# 17                            Edge of Tomorrow        2014   178.0  100.19
# 39                           The Little Prince        2015    81.2    1.34
# 22                                        Hugo        2011   170.0   73.82
#
#            actor_1_name       actor_2_name           actor_3_name  \
# ...

# %%
# Get the top 10 profitable movies by using position based indexing.
data[:10]
# Out:
#                                          Title  title_year  budget   Gross  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0  936.66
# 11                                The Avengers        2012   220.0  623.28
# 47                                    Deadpool        2016    58.0  363.02
# 32             The Hunger Games: Catching Fire        2013   130.0  424.65
# 12                                 Toy Story 3        2010   200.0  414.98
# 8                        The Dark Knight Rises        2012   250.0  448.13
# 45                              The Lego Movie        2014    60.0  257.76
# 1                                     Zootopia        2016   150.0  341.27
# 41                               Despicable Me        2010    69.0  251.50
# 18                                  Inside Out        2015   175.0  356.45
#
#          actor_1_name       actor_2_name           actor_3_name  \
# 97        Doug Walker         Rob Walker                      0
# ...

# %%
#Plot profit vs budget
data.plot(kind = 'scatter', y = 'budget', x = 'profit')
plt.show()

# %% [markdown]
# The dataset contains the 100 best performing movies from the year 2010 to 2016. However, the scatter plot tells a different story. We can notice that there are some movies with negative profit. Although good movies do incur losses, but there appear to be quite a few movie with losses. What can be the reason behind this? Lets have a closer look at this by finding the movies with negative profit.

# %%
#Find the movies with negative profit
data[data['profit']<0]
# Out:
#                           Title  title_year  budget   Gross  \
# 99      Tucker and Dale vs Evil        2010     5.0    0.22
# 89                        Amour        2012     8.9    0.23
# 56                         Rush        2013    38.0   26.90
# 66                      Warrior        2011    25.0   13.65
# 82                      Flipped        2010    14.0    1.75
# 28           X-Men: First Class        2011   160.0  146.41
# 46  Scott Pilgrim vs. the World        2010    60.0   31.49
# 7                       Tangled        2010   260.0  200.81
# 17             Edge of Tomorrow        2014   178.0  100.19
# 39            The Little Prince        2015    81.2    1.34
# 22                         Hugo        2011   170.0   73.82
#
#            actor_1_name        actor_2_name            actor_3_name  \
# 99       Katrina Bowden        Tyler Labine          Chelan Simmons
# 89     Isabelle Huppert     Emmanuelle Riva  Jean-Louis Trintignant
# ...

# %% [markdown]
# - ### The General Audience and the Critics
#
# We can see the column `MetaCritic` in this dataset. This is a very popular website where an average score is determined through the scores given by the top-rated critics. Second, we also have another column `IMDb_rating` which tells us the IMDb rating of a movie. This rating is determined by taking the average of hundred-thousands of ratings from the general audience.
#
# We will now find out the highest rated movies which have been liked by critics and audiences alike.
# 1. Firstly we can notice that the `MetaCritic` score is on a scale of `100` whereas the `IMDb_rating` is on a scale of 10. First convert the `MetaCritic` column to a scale of 10.
# 2. Now, to find out the movies which have been liked by both critics and audiences alike and also have a high rating overall, we need to -
#     - Create a new column `Avg_rating` which will have the average of the `MetaCritic` and `Rating` columns
#     - Retain only the movies in which the absolute difference(using abs() function) between the `IMDb_rating` and `Metacritic` columns is less than 0.5.
#     - Sort these values in a descending order of `Avg_rating` and retain only the movies with a rating equal to or greater than `8` and store these movies in a new dataframe `UniversalAcclaim`.

# %%
# Change the scale of MetaCritic
data['MetaCritic'] = (data['MetaCritic']/10).round(1)

# %%
# Find the average ratings
data['Avg_rating'] = ((data['MetaCritic']+data['IMDb_rating'])/2).round(1)
data
# Out:
#                                          Title  title_year  budget   Gross  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0  936.66
# 11                                The Avengers        2012   220.0  623.28
# 47                                    Deadpool        2016    58.0  363.02
# 32             The Hunger Games: Catching Fire        2013   130.0  424.65
# 12                                 Toy Story 3        2010   200.0  414.98
# ..                                         ...         ...     ...     ...
# 46                 Scott Pilgrim vs. the World        2010    60.0   31.49
# 7                                      Tangled        2010   260.0  200.81
# 17                            Edge of Tomorrow        2014   178.0  100.19
# 39                           The Little Prince        2015    81.2    1.34
# 22                                        Hugo        2011   170.0   73.82
#
#            actor_1_name       actor_2_name           actor_3_name  \
# ...

# %%
#Sort in descending order of average rating
data.sort_values(by=['Avg_rating'], ascending=False, inplace=True)
data
# Out:
#                                 Title  title_year  budget   Gross  \
# 94                            Boyhood        2014     4.0   25.36
# 18                         Inside Out        2015   175.0  356.45
# 69                   12 Years a Slave        2013    20.0   56.67
# 0                          La La Land        2016    30.0  151.10
# 4               Manchester by the Sea        2016     9.0   47.70
# ..                                ...         ...     ...     ...
# 16  The Hobbit: An Unexpected Journey        2012   180.0  303.00
# 52                      Lone Survivor        2013    40.0  125.07
# 88                         About Time        2013    12.0   15.29
# 71                     The Book Thief        2013    19.0   21.48
# 82                            Flipped        2010    14.0    1.75
#
#           actor_1_name        actor_2_name    actor_3_name  \
# 94      Ellar Coltrane   Lorelei Linklater   Libby Villari
# ...

# %%
# Find the movies with metacritic-Imdb rating < 0.5 and also with an average rating of >= 8 (sorted in descending order)
data[(data['MetaCritic']-data['IMDb_rating']<0.5) & (data['Avg_rating']>=8)]
# Out:
#                                          Title  title_year  budget   Gross  \
# 95                                    Whiplash        2014     3.3   13.09
# 93                          Dallas Buyers Club        2013     5.0   27.30
# 35                            Django Unchained        2012   100.0  162.80
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0  936.66
# 8                        The Dark Knight Rises        2012   250.0  448.13
# 27                                   Inception        2010   160.0  292.57
# 83                                  Black Swan        2010    13.0  106.95
# 62                               The Big Short        2015    28.0   70.24
# 1                                     Zootopia        2016   150.0  341.27
# 26                                Interstellar        2014   165.0  187.99
# 13                                     Skyfall        2012   200.0  304.36
# ...

# %% [markdown]
# - ### Find the Most Popular Trios - I
#
# The metric that we've chosen to check the popularity is the Facebook likes of each of 3 actors.
#
# The dataframe has three columns to help us for the same, viz. `actor_1_facebook_likes`, `actor_2_facebook_likes`, and `actor_3_facebook_likes`. Our objective is to find the trios which has the most number of Facebook likes combined. That is, the sum of `actor_1_facebook_likes`, `actor_2_facebook_likes` and `actor_3_facebook_likes` should be maximum.
# We will find out the top 5 popular trios, and output their names in a list.

# %%
# Creating a new datafram 'trios', having the names and facebook likes of all actors.
trios = data[['actor_1_name','actor_2_name','actor_3_name','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes']]

# Creating a new 'sum_of_likes' to store the likes of all 3 actors and then sorting them in descending order
trios['sum_of_likes'] = data['actor_1_facebook_likes']+data['actor_2_facebook_likes']+data['actor_3_facebook_likes']
trios.sort_values(by=['sum_of_likes'], ascending=False, inplace=True)

# Storing the names of top 5 set of actors in 'names' dataframe
names = trios.iloc[:,:3].head()

# Converting 'names' to a list
trios_list = names.values.tolist()
trios_list
# Out:
# [['Dev Patel', 'Nicole Kidman', 'Rooney Mara'],
#  ['Leonardo DiCaprio', 'Tom Hardy', 'Joseph Gordon-Levitt'],
#  ['Jennifer Lawrence', 'Peter Dinklage', 'Hugh Jackman'],
#  ['Casey Affleck', 'Michelle Williams ', 'Kyle Chandler'],
#  ['Tom Hardy', 'Christian Bale', 'Joseph Gordon-Levitt']]

# %% [markdown]
# - ### Find the Most Popular Trios - II
#
# Let's add a small condition to the previous operation and make sure that all three actors are popular. The condition is **none of the three actors' Facebook likes should be less than half of the other two**. For example, the following is a valid combo:
# - actor_1_facebook_likes: 70000
# - actor_2_facebook_likes: 40000
# - actor_3_facebook_likes: 50000
#
# But the below one is not:
# - actor_1_facebook_likes: 70000
# - actor_2_facebook_likes: 40000
# - actor_3_facebook_likes: 30000
#
# since in this case, `actor_3_facebook_likes` is 30000, which is less than half of `actor_1_facebook_likes`.
#
# Having this condition ensures that we aren't getting any unpopular actor in our trio (since the total likes calculated in the previous operation doesn't tell anything about the individual popularities of each actor in the trio.).

# %%
# Storing index in 'temp_ind' of trios that don't satisfy our condition.
temp_ind = trios[ (trios['actor_1_facebook_likes']<trios['actor_2_facebook_likes']/2) | (trios['actor_1_facebook_likes']<trios['actor_3_facebook_likes']/2) | (trios['actor_2_facebook_likes']<trios['actor_1_facebook_likes']/2) | (trios['actor_2_facebook_likes']<trios['actor_3_facebook_likes']/2) | (trios['actor_3_facebook_likes']<trios['actor_1_facebook_likes']/2) | (trios['actor_3_facebook_likes']<trios['actor_2_facebook_likes']/2)].index

# Dropping the rows from 'trios' that don't satisfy our condition
trios.drop(temp_ind, inplace=True)

# Storing the names of top 5 set of actors in 'names1' dataframe
names1 = trios.iloc[:,:3].head()

# Converting 'names' to a list
trios_list1 = names1.values.tolist()
trios_list1
# Out:
# [['Leonardo DiCaprio', 'Tom Hardy', 'Joseph Gordon-Levitt'],
#  ['Jennifer Lawrence', 'Peter Dinklage', 'Hugh Jackman'],
#  ['Tom Hardy', 'Christian Bale', 'Joseph Gordon-Levitt'],
#  ['Chris Hemsworth', 'Robert Downey Jr.', 'Scarlett Johansson'],
#  ['Philip Seymour Hoffman', 'Robin Wright', 'Brad Pitt']]

# %% [markdown]
# - ### Runtime Analysis
#
# There is a column named `Runtime` in the dataframe which primarily shows the length of the movie. It might be intersting to see how this variable this distributed. Plot a `histogram` or `distplot` of seaborn to find the `Runtime` range most of the movies fall into.

# %%
# Runtime histogram/density plot
sns.histplot(data=data, x="Runtime")
# Out:
# <AxesSubplot:xlabel='Runtime', ylabel='Count'>

# %% [markdown]
# - ### R-Rated Movies
#
# Although R rated movies are restricted movies for the under 18 age group, still there are vote counts from that age group. Among all the R rated movies that have been voted by the under-18 age group, we will find the top 10 movies that have the highest number of votes i.e.`CVotesU18` from the `movies` dataframe. Store these in a dataframe named `PopularR`.

# %%
PopularR = data[data['content_rating']=='R']
PopularR.sort_values(by=['CVotesU18'], ascending=False, inplace=True)
PopularR.head(10)
# Out:
#                                               Title  title_year  budget  \
# 47                                         Deadpool        2016    58.0
# 36                          The Wolf of Wall Street        2013   100.0
# 35                                 Django Unchained        2012   100.0
# 29                               Mad Max: Fury Road        2015   150.0
# 95                                         Whiplash        2014     3.3
# 31                                     The Revenant        2015   135.0
# 40                                   Shutter Island        2010    80.0
# 43                                        Gone Girl        2014    61.0
# 65                         The Grand Budapest Hotel        2014    25.0
# 72  Birdman or (The Unexpected Virtue of Ignorance)        2014    18.0
#
#      Gross       actor_1_name         actor_2_name       actor_3_name  \
# 47  363.02      Ryan Reynolds            Ed Skrein     Stefan Kapicic
# ...

# %% [markdown]
# ## Demographic analysis
#
# If we take a look at the last columns in the dataframe, most of these are related to demographics of the voters. We also have three genre columns indicating the genres of a particular movie. We will extensively use these columns to analyse the voters across all demographics and also see how these vary across various genres.

# %% [markdown]
# -  ### Combine the Dataframe by Genres
#
# There are 3 columns in the dataframe - `genre_1`, `genre_2`, and `genre_3`. We need to aggregate a few values over these 3 columns.
# 1. First create a new dataframe `df_by_genre` that contains `genre_1`, `genre_2`, and `genre_3` and all the columns related to **CVotes/Votes** from the `movies` data frame.
# 2. Now, add a column called `cnt` to the dataframe `df_by_genre` and initialize it to one.
# 3. First group the dataframe `df_by_genre` by `genre_1` and find the sum of all the numeric columns such as `cnt`, columns related to CVotes and Votes columns and store it in a dataframe `df_by_g1`.
# 4. Perform the same operation for `genre_2` and `genre_3` and store it dataframes `df_by_g2` and `df_by_g3` respectively.
# 5. Now that we have 3 dataframes performed by grouping over `genre_1`, `genre_2`, and `genre_3` separately, it's time to combine them. For this, add the three dataframes and store it in a new dataframe `df_add`, so that the corresponding values of Votes/CVotes get added for each genre.
# 6. The column `cnt` on aggregation has basically kept the track of the number of occurences of each genre.Subset the genres that have atleast 10 movies into a new dataframe `genre_top10` based on the `cnt` column value.
# 7. Now, take the mean of all the numeric columns by dividing them with the column value `cnt` and store it back to the same dataframe.
# 8. Since the number of votes can't be a fraction, type cast all the CVotes related columns to integers. Also, round off all the Votes related columns upto two digits after the decimal point.

# %%
# Create the dataframe df_by_genre
df_by_genre1 = data.iloc[:,11:14]
df_by_genre2 = data.iloc[:,16:60]
df_by_genre = df_by_genre1.join(df_by_genre2)
df_by_genre
# Out:
#       genre_1    genre_2  genre_3  CVotes10  CVotes09  CVotes08  CVotes07  \
# 94      Drama        NaN      NaN     49673     62055     76838     52238
# 18  Animation  Adventure   Comedy     87509    113244    119801     67153
# 69  Biography      Drama  History     75556    126223    161460     83070
# 0      Comedy      Drama    Music     74245     71191     64640     38831
# 4       Drama        NaN      NaN     18191     33532     46596     29626
# ..        ...        ...      ...       ...       ...       ...       ...
# 16  Adventure    Fantasy      NaN    135848    132202    191128    122538
# 52     Action  Biography    Drama     30856     33356     68808     54195
# 88     Comedy      Drama  Fantasy     38556     43170     70850     45487
# 71      Drama        War      NaN     15911     17607     32570     24461
# 82     Comedy      Drama  Romance     11354     11050     20808     14372
#
#     CVotes06  CVotes05  CVotes04  ...  Votes1829F  Votes3044  Votes3044M  \
# ...

# %%
# Create a column cnt and initialize it to 1
df_by_genre['cnt'] = 1
df_by_genre
# Out:
#       genre_1    genre_2  genre_3  CVotes10  CVotes09  CVotes08  CVotes07  \
# 94      Drama        NaN      NaN     49673     62055     76838     52238
# 18  Animation  Adventure   Comedy     87509    113244    119801     67153
# 69  Biography      Drama  History     75556    126223    161460     83070
# 0      Comedy      Drama    Music     74245     71191     64640     38831
# 4       Drama        NaN      NaN     18191     33532     46596     29626
# ..        ...        ...      ...       ...       ...       ...       ...
# 16  Adventure    Fantasy      NaN    135848    132202    191128    122538
# 52     Action  Biography    Drama     30856     33356     68808     54195
# 88     Comedy      Drama  Fantasy     38556     43170     70850     45487
# 71      Drama        War      NaN     15911     17607     32570     24461
# 82     Comedy      Drama  Romance     11354     11050     20808     14372
#
#     CVotes06  CVotes05  CVotes04  ...  Votes3044  Votes3044M  Votes3044F  \
# ...

# %%
# Group the movies by individual genres
df_by_g1 = df_by_genre.groupby(by='genre_1').sum()
df_by_g2 = df_by_genre.groupby(by='genre_2').sum()
df_by_g3 = df_by_genre.groupby(by='genre_3').sum()

# %%
# Add the grouped data frames and store it in a new data frame
df_add = df_by_g1.add(df_by_g2.add(df_by_g3, fill_value=0), fill_value=0)
df_add
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Family       98165.0    95675.0   180381.0   143401.0    59137.0   22971.0
# Fantasy     572452.0   602223.0   889767.0   599747.0   241831.0   93484.0
# History     151261.0   260387.0   394531.0   223062.0    67861.0   21233.0
# Horror       16572.0    19818.0    44460.0    35863.0    13456.0    4588.0
# ...

# %%
# Extract genres with atleast 10 occurences
genre_top10 = df_add[df_add['cnt']>=10]
genre_top10
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Romance     549959.0   689492.0  1069280.0   712841.0   281289.0  110901.0
# Sci-Fi     2325284.0  2530855.0  3002994.0  1802098.0   671811.0  254175.0
# Thriller   1081701.0  1465491.0  1993378.0  1175799.0   416046.0  149953.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# ...

# %%
# Take the mean for every column by dividing with cnt 
genre_top10.iloc[:,:44] = genre_top10.iloc[:,:44].div(genre_top10.cnt, axis=0)
genre_top10
# Out:
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Action     102144.096774  114433.193548  150895.322581   94262.129032
# Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# Animation   61960.181818   72566.090909  104837.636364   65707.454545
# Biography   47333.500000   77867.111111  123948.777778   74054.444444
# Comedy      60157.217391   77173.347826  108993.521739   69176.913043
# Crime       52229.636364   87919.818182  129045.000000   74671.818182
# Drama       52375.969231   75928.846154  109339.276923   66456.923077
# Romance     42304.538462   53037.846154   82252.307692   54833.923077
# Sci-Fi     136781.411765  148873.823529  176646.705882  106005.764706
# Thriller    83207.769231  112730.076923  153336.769231   90446.076923
#
#                CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  \
# Action     34688.838710  12693.032258  5386.129032  3064.645161  2115.258065
# ...

# %%
# Rounding off the columns of Votes to two decimals
genre_top10.iloc[:,:44] = genre_top10.iloc[:,:44].round(2)
genre_top10
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07  CVotes06  CVotes05  \
# Action     102144.10  114433.19  150895.32   94262.13  34688.84  12693.03
# Adventure   94596.29  105636.63  138482.32   86367.92  31896.71  11551.84
# Animation   61960.18   72566.09  104837.64   65707.45  22825.09   7551.73
# Biography   47333.50   77867.11  123948.78   74054.44  23644.17   7702.67
# Comedy      60157.22   77173.35  108993.52   69176.91  26099.43   9863.13
# Crime       52229.64   87919.82  129045.00   74671.82  25308.27   8971.82
# Drama       52375.97   75928.85  109339.28   66456.92  23528.55   8497.11
# Romance     42304.54   53037.85   82252.31   54833.92  21637.62   8530.85
# Sci-Fi     136781.41  148873.82  176646.71  106005.76  39518.29  14951.47
# Thriller    83207.77  112730.08  153336.77   90446.08  32003.54  11534.85
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# ...

# %%
# Converting CVotes to int type
temp = list(genre_top10.columns[:27])
genre_top10[temp] = genre_top10[temp].astype(int)
genre_top10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action       102144    114433    150895     94262     34688     12693
# Adventure     94596    105636    138482     86367     31896     11551
# Animation     61960     72566    104837     65707     22825      7551
# Biography     47333     77867    123948     74054     23644      7702
# Comedy        60157     77173    108993     69176     26099      9863
# Crime         52229     87919    129045     74671     25308      8971
# Drama         52375     75928    109339     66456     23528      8497
# Romance       42304     53037     82252     54833     21637      8530
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Thriller      83207    112730    153336     90446     32003     11534
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# Action         5386      3064      2115      5524  ...       7.74        7.73
# ...

# %% [markdown]
# We can use this dataset to extract exciting insights about the voters!

# %% [markdown]
# -  ### Most Popular Genre

# %%
# Countplot for genres
sns.set(rc={"figure.figsize":(10, 4)})
sns.barplot(data=genre_top10, x=genre_top10.index, y="cnt", width=0.5)
# Out:
# <AxesSubplot:ylabel='cnt'>

# %% [markdown]
# We can observe that `Drama` is the most popular `Genre`.

# %% [markdown]
# -  ### Gender and Genre
#
# Since we have the vote counts for both males and females, across various age groups, let's now see how the popularity of genres vary between the two genders in the dataframe.
#
# 1. Make the first heatmap to see how the average number of votes of males is varying across the genres. Use seaborn heatmap for this analysis. The X-axis should contain the four age-groups for males, i.e., `CVotesU18M`,`CVotes1829M`, `CVotes3044M`, and `CVotes45AM`. The Y-axis will have the genres and the annotation in the heatmap tell the average number of votes for that age-male group.
#
# 2. Make the second heatmap to see how the average number of votes of females is varying across the genres. Use seaborn heatmap for this analysis. The X-axis should contain the four age-groups for females, i.e., `CVotesU18F`,`CVotes1829F`, `CVotes3044F`, and `CVotes45AF`. The Y-axis will have the genres and the annotation in the heatmap tell the average number of votes for that age-female group.
#
# 3. We will plot these heatmaps side by side using `subplots` so that we can easily compare the two genders and derive insights.
#
# 4. Repeat 1 to 3, but now instead of taking the CVotes-related columns, we need to do the same process for the Votes-related columns. These heatmaps will show us how the two genders have rated movies across various genres.
#
# -  Note : We will use `genre_top10` dataframe for this analysis

# %%
# 1st set of heat maps for CVotes-related columns
plt.rcParams["figure.figsize"] = [20.00, 8.0]
sns.set()
fig, axes = plt.subplots(1, 2)
sns.heatmap(genre_top10[["CVotesU18M","CVotes1829M", "CVotes3044M", "CVotes45AM"]], ax=axes[0])
sns.heatmap(genre_top10[["CVotesU18F","CVotes1829F", "CVotes3044F", "CVotes45AF"]], ax=axes[1])
# Out:
# <AxesSubplot:>

# %% [markdown]
# **`Inferences:`**
# - Males have voted more than females, and Sci-Fi appears to be most popular among the 18-29 age group irrespective of their gender.
# - Age groups Under-18 and 45-Above have voted the least irrespective of the gender.
# - For 18-29 age group, the votes are evenly distributed for females as compared to males.
# - Though there are maximum movies in Drama genre, the votes are not that high for both genders across all age groups.

# %%
# 2nd set of heat maps for Votes-related columns
plt.rcParams["figure.figsize"] = [20.00, 8.0]
sns.set()
fig, axes = plt.subplots(1, 2)
sns.heatmap(genre_top10[["VotesU18M","Votes1829M", "Votes3044M", "Votes45AM"]], ax=axes[0])
sns.heatmap(genre_top10[["VotesU18F","Votes1829F", "Votes3044F", "Votes45AF"]], ax=axes[1])
# Out:
# <AxesSubplot:>

# %% [markdown]
# **`Inferences:`**
# - Sci-Fi appears to be the highest rated genre in the age group of U18 for both males and females. Also, females in this age group have rated it a bit higher than the males in the same age group.
# - For both genders the ratings tend to decrease as we move from lower to higher age groups.
# - For Under-18 age group, the males tend rate crime much higher than females.
# - Animation genre is better rated by females than by males across age groups.

# %% [markdown]
# -  ### US vs non-US Cross Analysis
#
# The dataset contains both the US and non-US movies. Let's analyse how both the US and the non-US voters have responded to the US and the non-US movies.
#
# 1. Create a column `IFUS` in the dataframe `movies`. The column `IFUS` should contain the value "USA" if the `Country` of the movie is "USA". For all other countries other than the USA, `IFUS` should contain the value `non-USA`.
#
# 2. Now make a boxplot that shows how the number of votes from the US people i.e. `CVotesUS` is varying for the US and non-US movies. Make use of the column `IFUS` to make this plot. Similarly, make another subplot that shows how non US voters have voted for the US and non-US movies by plotting `CVotesnUS` for both the US and non-US movies. Write any of your two inferences/observations from these plots.
#
# 3. Again we will do a similar analysis but with the ratings. Make a boxplot that shows how the ratings from the US people i.e. `VotesUS` is varying for the US and non-US movies. Similarly, make another subplot that shows how `VotesnUS` is varying for the US and non-US movies.
#
# Note : We will use `movies` dataframe for this subtask.

# %%
# Creating IFUS column
movies = data
movies['IFUS'] = np.where(movies['Country']!= 'USA', 'non-USA', 'USA')
movies
# Out:
#                                 Title  title_year  budget   Gross  \
# 94                            Boyhood        2014     4.0   25.36
# 18                         Inside Out        2015   175.0  356.45
# 69                   12 Years a Slave        2013    20.0   56.67
# 0                          La La Land        2016    30.0  151.10
# 4               Manchester by the Sea        2016     9.0   47.70
# ..                                ...         ...     ...     ...
# 16  The Hobbit: An Unexpected Journey        2012   180.0  303.00
# 52                      Lone Survivor        2013    40.0  125.07
# 88                         About Time        2013    12.0   15.29
# 71                     The Book Thief        2013    19.0   21.48
# 82                            Flipped        2010    14.0    1.75
#
#           actor_1_name        actor_2_name    actor_3_name  \
# 94      Ellar Coltrane   Lorelei Linklater   Libby Villari
# ...

# %%
# Box plot - 1: CVotesUS(y) vs IFUS(x)
plt.rcParams["figure.figsize"] = [20.00, 8.0]
sns.set()
fig, axes = plt.subplots(1, 2)
sns.boxplot(y=movies["CVotesUS"], x=movies["IFUS"], ax=axes[0])
sns.boxplot(y=movies["CVotesnUS"], x=movies["IFUS"], ax=axes[1])
# Out:
# <AxesSubplot:xlabel='IFUS', ylabel='CVotesnUS'>

# %% [markdown]
# **`Inferences:`**
# - The votes from non US people are considerably higher than that of US people.
# - The number of votes is much higher for movies from US irrespective of to which country the person belongs.

# %%
# Box plot - 2: VotesUS(y) vs IFUS(x)
plt.rcParams["figure.figsize"] = [20.00, 8.0]
sns.set()
fig, axes = plt.subplots(1, 2)
sns.boxplot(y=movies["VotesUS"], x=movies["IFUS"], ax=axes[0])
sns.boxplot(y=movies["VotesnUS"], x=movies["IFUS"], ax=axes[1])
# Out:
# <AxesSubplot:xlabel='IFUS', ylabel='VotesnUS'>

# %% [markdown]
# **`Inferences:`**
# - The IQR is more for the country from which the voters are.
# - The range of ratings is much higher for movies from US irrespective of to which country the person belongs.

# %% [markdown]
# -  ### Top 1000 Voters Vs Genres
#
# The column `CVotes1000` represents the top 1000 voters on IMDb and gives the count for the number of these voters who have voted for a particular movie. Let's see how these top 1000 voters have voted across the genres.
#
# 1. Sort the dataframe genre_top10 based on the value of `CVotes1000`in a descending order.
#
# 2. Make a seaborn barplot for `genre` vs `CVotes1000`.

# %%
# Sorting by CVotes1000
genre_top10.sort_values(by=['CVotes1000'], ascending=False, inplace=True)
genre_top10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Action       102144    114433    150895     94262     34688     12693
# Thriller      83207    112730    153336     90446     32003     11534
# Adventure     94596    105636    138482     86367     31896     11551
# Crime         52229     87919    129045     74671     25308      8971
# Comedy        60157     77173    108993     69176     26099      9863
# Biography     47333     77867    123948     74054     23644      7702
# Drama         52375     75928    109339     66456     23528      8497
# Animation     61960     72566    104837     65707     22825      7551
# Romance       42304     53037     82252     54833     21637      8530
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# Sci-Fi         6583      3876      2715      6731  ...       7.86        7.85
# ...

# %%
# Bar plot
sns.set(rc={"figure.figsize":(10, 4)})
sns.barplot(data=genre_top10, x=genre_top10.index, y="CVotes1000", width=0.5)
# Out:
# <AxesSubplot:ylabel='CVotes1000'>

# %% [markdown]
# **`Inferences:`**
# - Sci-Fi is the most rated genre for top 1000 voters as well.
# - No genre has votes from all the top 1000 voters.
# - The genre `Romance` seems to be most unpopular among the top 1000 voters.
